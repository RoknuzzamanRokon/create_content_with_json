# %% [markdown]
# ## GoGlobal

# %%
import requests

url = "https://gtr.xml.goglobal.travel/xmlwebservice.asmx"

payload = """<?xml version="1.0" encoding="utf-8"?>
    <soap12:Envelope xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" 
                 xmlns:xsd="http://www.w3.org/2001/XMLSchema" 
                 xmlns:soap12="http://www.w3.org/2003/05/soap-envelope">
        <soap12:Body>
            <MakeRequest xmlns="http://www.goglobal.travel/">
                    <requestType>6</requestType>
                    <xmlRequest>
                        <![CDATA[
                            <Root>
                                <Header>
                                    <Agency>149548</Agency>
                                    <User>NOFSHONXMLTEST</User>
                                    <Password>W99IL98KY1G</Password>
                                    <Operation>HOTEL_INFO_REQUEST</Operation>
                                    <OperationType>Request</OperationType>
                                </Header>
                                <Main Version="2.2">
                                    <InfoHotelId>1000076</InfoHotelId>
                                    <InfoLanguage>en</InfoLanguage>
                                </Main>
                            </Root>
                        ]]>
                    </xmlRequest>
            </MakeRequest>
        </soap12:Body>
    </soap12:Envelope>"""


headers = {
          'Content-Type': 'application/soap+xml; charset=utf-8',
          'API-Operation': 'HOTEL_INFO_REQUEST'
        }

# response = requests.request("POST", url, headers=headers, data=payload)

# print(response.text)


try:
    response = requests.post(url, data=payload, headers=headers)
    response.raise_for_status()  
    print("Response:")
    print(response.text)
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# Response:
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><MakeRequestResponse xmlns="http://www.goglobal.travel/"><MakeRequestResult>&lt;Root&gt;&lt;Header&gt;&lt;Agency&gt;149548&lt;/Agency&gt;&lt;User&gt;NOFSHONXMLTEST&lt;/User&gt;&lt;Password&gt;&lt;/Password&gt;&lt;Operation&gt;HOTEL_INFO_RESPONSE&lt;/Operation&gt;&lt;OperationType&gt;Response&lt;/OperationType&gt;&lt;/Header&gt;&lt;Main&gt;&lt;HotelSearchCode&gt;&lt;![CDATA[]]&gt;&lt;/HotelSearchCode&gt;&lt;HotelName&gt;&lt;![CDATA[Kriukot]]&gt;&lt;/HotelName&gt;&lt;HotelId&gt;&lt;![CDATA[1000076]]&gt;&lt;/HotelId&gt;&lt;Address&gt;&lt;![CDATA[Hafnarbraut 17, 510, Hólmavík, ICELAND]]&gt;&lt;/Address&gt;&lt;CityCode&gt;&lt;![CDATA[122065]]&gt;&lt;/CityCode&gt;&lt;Phone&gt;&lt;![CDATA[]]&gt;&lt;/Phone&gt;&lt;Fax&gt;&lt;![CDATA[]]&gt;&lt;/Fax&gt;&lt;Category&gt;&lt;![CDATA[0]]&gt;&lt;/Category&gt;&lt;Description&gt;&lt;![CDATA[Kriukot in Hólmavík provides accommodations with a garden and a terrace. This guest house provides free private parking, a shared kitchen, and free Wifi. The accommodation offers daily room service and a shared lounge for guests. The guest house features certain units with sea views, and units are equipped with a shared bathroom. At the guest house, all units are fitted with bed linen and towels. The nearest airport is Isafjordur Airport, 135 miles from the guest house.WiFi is available in all areas and is free of charge.
# &lt;BR /&gt;Free private parking is available  on site (reservation is not needed).
# &lt;BR /&gt;Pets are not allowed.
# &lt;BR /&gt;Children of all ages are allowed.
sanitizer&lt;BR /&gt;&lt;b&gt;Room Type: Twin &lt;/b&gt;&lt;BR /&gt;Shared bathroom&lt;BR /&gt;Free toiletries&lt;BR /&gt;Extra long beds (&gt; 6.5 ft)&lt;BR /&gt;Heating&lt;BR /&gt;Shared toilet&lt;BR /&gt;View&lt;BR /&gt;Hardwood or parquet floors&lt;BR /&gt;Garden view&lt;BR /&gt;Towels&lt;BR /&gt;Linens&lt;BR /&gt;Entire unit located on ground floor&lt;BR /&gt;Clothes rack&lt;BR /&gt;Toilet paper&lt;BR /&gt;Body soap&lt;BR /&gt;Socket near the bed&lt;BR /&gt;Adapter&lt;BR /&gt;Non-feather pillow&lt;BR /&gt;Inner courtyard view&lt;BR /&gt;Mobile hotspot device&lt;BR /&gt;Key access&lt;BR /&gt;Hand sanitizer&lt;BR /&gt;&lt;b&gt;Room Type: Double &lt;/b&gt;&lt;BR /&gt;Shared bathroom&lt;BR /&gt;Free toiletries&lt;BR /&gt;Extra long beds (&gt; 6.5 ft)&lt;BR /&gt;Heating&lt;BR /&gt;Shared toilet&lt;BR /&gt;View&lt;BR /&gt;Hardwood or parquet floors&lt;BR /&gt;Sea view&lt;BR /&gt;Mountain view&lt;BR /&gt;Towels&lt;BR /&gt;Linens&lt;BR /&gt;Entire unit located on ground floor&lt;BR /&gt;Clothes rack&lt;BR /&gt;Toilet paper&lt;BR /&gt;Childrens' cribs&lt;BR /&gt;Body soap&lt;BR /&gt;Socket near the bed&lt;BR /&gt;Adapter&lt;BR /&gt;Non- ...

# %%
import requests
import xmltodict
import json

import requests

url = "https://gtr.xml.goglobal.travel/xmlwebservice.asmx"

payload = """<?xml version="1.0" encoding="utf-8"?>
    <soap12:Envelope xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" 
                 xmlns:xsd="http://www.w3.org/2001/XMLSchema" 
                 xmlns:soap12="http://www.w3.org/2003/05/soap-envelope">
        <soap12:Body>
            <MakeRequest xmlns="http://www.goglobal.travel/">
                    <requestType>6</requestType>
                    <xmlRequest>
                        <![CDATA[
                            <Root>
                                <Header>
                                    <Agency>149548</Agency>
                                    <User>NOFSHONXMLTEST</User>
                                    <Password>W99IL98KY1G</Password>
                                    <Operation>HOTEL_INFO_REQUEST</Operation>
                                    <OperationType>Request</OperationType>
                                </Header>
                                <Main Version="2.2">
                                    <InfoHotelId>10000</InfoHotelId>
                                    <InfoLanguage>en</InfoLanguage>
                                </Main>
                            </Root>
                        ]]>
                    </xmlRequest>
            </MakeRequest>
        </soap12:Body>
    </soap12:Envelope>"""


headers = {
          'Content-Type': 'application/soap+xml; charset=utf-8',
          'API-Operation': 'HOTEL_INFO_REQUEST'
        }



try:
    response = requests.post(url, data=payload, headers=headers)
    response.raise_for_status() 

    # Parse the XML response into a dictionary
    parsed_response = xmltodict.parse(response.text)
    
    # Convert the dictionary to JSON format
    json_response = json.dumps(parsed_response, indent=4)
    
    print("Response in JSON format:")
    print(json_response)
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
except Exception as e:
    print(f"An error occurred during parsing: {e}")
# Out:
# Response in JSON format:
# {
#     "soap:Envelope": {
#         "@xmlns:soap": "http://www.w3.org/2003/05/soap-envelope",
#         "@xmlns:xsi": "http://www.w3.org/2001/XMLSchema-instance",
Shower<BR />Bathtub<BR />Safe<BR />Pay-per-view channels<BR />Telephone<BR />Air conditioning<BR />Hairdryer<BR />Suit press<BR />Bathrobe<BR />Toilet<BR />Private Bathroom<BR />Slippers<BR />Satellite channels<BR />Flat-screen TV<BR /><b>Room Type: Suite </b><BR />Minibar<BR />Shower<BR />Bathtub<BR />Safe<BR />Pay-per-view channels<BR />Telephone<BR />Air conditioning<BR />Hairdryer<BR />Suit press<BR />Bathrobe<BR />Sitting area<BR />Toilet<BR />Private Bathroom<BR />Slippers<BR />Satellite channels<BR />Flat-screen TV<BR />]]></RoomFacilities><RoomCount><![CDATA[]]></RoomCount><Pictures><Picture Description=\"Primary image\"><![CDATA[https://i.travelapi.com/lodging/1000000/30000/27400/27370/e2e83bf9_b.jpg]]></Picture><Picture Description=\"Reception\"><![CDATA[https://i.travelapi.com/lodging/1000000/30000/27400/27370/ ...
#             }
#         }
#     }
# }

# %%
import xml.etree.ElementTree as ET

# Extracting the MakeRequestResult field
xml_data = parsed_response["soap:Envelope"]["soap:Body"]["MakeRequestResponse"]["MakeRequestResult"]

# print(xml_data)

# Parsing the XML data
root = ET.fromstring(xml_data)

hotel_name = root.find(".//HotelName").text  
hotel_search_code = root.find(".//HotelSearchCode").text
hotel_id = root.find(".//HotelId").text
hotel_address = root.find(".//Address").text
hotel_citycode = root.find(".//CityCode").text
hotel_phone = root.find(".//Phone").text
hotel_fax = root.find(".//Fax").text
hotel_description = root.find(".//Description").text

hotel_hotelFacilities = root.find(".//HotelFacilities").text
facilities_list = hotel_hotelFacilities.split("<BR />")

# Process each facility into the desired JSON structure
facilities_json = []
for facility in facilities_list:
    facility = facility.strip()  
    if facility:  
        facilities_json.append({
            "type": facility,
            "title": facility,
            "icon": "NULL"
        })


# print(f"hotel name = {facilities_json}")

# Proceess each room facility into content format.
hotel_roomFacilities = root.find(".//RoomFacilities").text
roomFacilities_list = hotel_roomFacilities.split("<BR />")

rm_facilities_json = []
for facility in roomFacilities_list:
    facility = facility.strip()
    if facility:
        rm_facilities_json.append({
            "type": facility,
            "title": facility,
            "icon": "NULL"
        })


# print(rm_facilities_json)


# This is picture section.
# hotel_picture = root.find(".//Pictures")
# print(hotel_picture)

pictures = root.find(".//Pictures")

# Initialize the photo_data list
photo_data = []

if pictures is not None:
    for picture in pictures.findall("Picture"):
        url = picture.text.strip() if picture.text else ""
        
        # Extract the Description attribute as title
        title = picture.attrib.get("Description", "")
        photo_data.append({
            "picture_id": "NULL",
            "title": title,
            "url": url
        })

# Print the result
print(photo_data)
# Out:
# [{'picture_id': 'NULL', 'title': 'Primary image', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/e2e83bf9_b.jpg'}, {'picture_id': 'NULL', 'title': 'Reception', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/ea4b29a1_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/21d04d39_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/a32fc00a_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/c6dbee7e_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/w982h667x18y0-050144aa_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/10fa604d_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/c9f14b30_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/1a3ec866_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/46276de1_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/03d5ef7e_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/d5b5084b_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room amenity', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/d251912e_b.jpg'}, {'picture_id': 'NULL', 'title': 'Room amenity', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/7ed686ce_b.jpg'}, {'picture_id': 'NULL', 'title': 'Bathroom', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/729ae73a_b.jpg'}, {'picture_id': 'NULL', 'title': 'Breakfast area', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/2d7ae523_b.jpg'}, {'picture_id': 'NULL', 'title': 'Bar (on property)', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/d10ce190_b.jpg'}, {'picture_id': 'NULL', 'title': 'Lounge', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/8257b1d4_b.jpg'}, {'picture_id': 'NULL', 'title': 'Interior', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/w651h1000x17y0-9be4efe8_b.jpg'}, {'picture_id': 'NULL', 'title': 'Interior', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/267e717b_b.jpg'}, {'picture_id': 'NULL', 'title': 'Library', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/c6117560_b.jpg'}, {'picture_id': 'NULL', 'title': 'Meeting facility', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/be3803eb_b.jpg'}, {'picture_id': 'NULL', 'title': 'Property entrance', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/4109f135_b.jpg'}, {'picture_id': 'NULL', 'title': '', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/656c7bce_b.jpg'}, {'picture_id': 'NULL', 'title': '', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/57394984_b.jpg'}, {'picture_id': 'NULL', 'title': '', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/70afdbbc_b.jpg'}, {'picture_id': 'NULL', 'title': '', 'url': 'https://i.travelapi.com/lodging/1000000/30000/27400/27370/fad8ab8c_b.jpg'}]
