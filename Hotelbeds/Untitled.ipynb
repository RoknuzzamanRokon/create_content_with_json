# %%
import requests
import hashlib
import time
import os
import pandas as pd
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Hotelbeds API credentials
API_KEY = os.getenv("HOTELBEDS_API_KEY")
API_SECRET = os.getenv("HOTELBEDS_API_SECRET")
BASE_URL = os.getenv("HOTELBEDS_BASE_URL")

# Define the batch size (up to 1000 hotels per request)
BATCH_SIZE = 1000


def generate_signature(api_key, secret):
    """Generate the Hotelbeds API signature."""
    timestamp = str(int(time.time()))
    signature_data = f"{api_key}{secret}{timestamp}"
    signature = hashlib.sha256(signature_data.encode('utf-8')).hexdigest()
    return signature


def fetch_hotel_data(from_index, to_index):
    """Fetch a batch of hotel data from the Hotelbeds API."""
    signature = generate_signature(API_KEY, API_SECRET)

    url = f"{BASE_URL}/hotel-content-api/1.0/hotels?fields=all&language=ENG&from={from_index}&to={to_index}&useSecondaryLanguage=false"

    headers = {
        "Content-Type": "application/json",
        "Api-key": API_KEY,
        "X-Signature": signature
    }

    response = requests.get(url, headers=headers, timeout=120)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: Received status code {response.status_code}")
        print(f"Response: {response.text}")
        return None


def process_and_save_to_csv(hotel_data, file_name):
    """Process hotel data and save it to a CSV file."""
    if not hotel_data or 'hotels' not in hotel_data:
        print("No hotel data found to process.")
        return

    hotels = hotel_data['hotels']
    df = pd.DataFrame(hotels)

    # Replace missing values with empty strings
    df.fillna(value="", inplace=True)

    try:
        # Append to CSV file
        if not os.path.isfile(file_name):
            df.to_csv(file_name, mode='w', index=False)
            print(f"CSV file created: {file_name}")
        else:
            df.to_csv(file_name, mode='a', header=False, index=False)
            print(f"Data appended to CSV file: {file_name}")
    except Exception as e:
        print(f"Error saving data to CSV: {e}")



def dump_hotel_data_to_csv(total_hotels, batch_size, file_name):
    """Dump all hotel data in batches to a CSV file."""
    print("Starting data dump process...")

    for from_index in range(1, total_hotels + 1, batch_size):
        to_index = min(from_index + batch_size - 1, total_hotels)
        print(f"Fetching hotels from {from_index} to {to_index}...")

        hotel_data = fetch_hotel_data(from_index, to_index)

        if hotel_data:
            process_and_save_to_csv(hotel_data, file_name)
        else:
            print(f"Skipping batch from {from_index} to {to_index} due to errors.")

        # Rate-limiting to avoid hitting API request limits
        time.sleep(2)

    print("Data dump process completed.")


if __name__ == "__main__":
    # Set the total number of hotels to fetch (e.g., 173,000)
    TOTAL_HOTELS = 173000

    # File where the data will be saved
    CSV_FILE_NAME = "hotelbeds_data.csv"

    # Start the dump process
    dump_hotel_data_to_csv(total_hotels=TOTAL_HOTELS, batch_size=BATCH_SIZE, file_name=CSV_FILE_NAME)
# Out:
# Starting data dump process...
# Fetching hotels from 1 to 1000...
# CSV file created: hotelbeds_data.csv
# Fetching hotels from 1001 to 2000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 2001 to 3000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 3001 to 4000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 4001 to 5000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 5001 to 6000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 6001 to 7000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 7001 to 8000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 8001 to 9000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 9001 to 10000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 10001 to 11000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 11001 to 12000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 12001 to 13000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 13001 to 14000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 14001 to 15000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 15001 to 16000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 16001 to 17000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 17001 to 18000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 18001 to 19000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 19001 to 20000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 20001 to 21000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 21001 to 22000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 22001 to 23000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 23001 to 24000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 24001 to 25000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 25001 to 26000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 26001 to 27000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 27001 to 28000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 28001 to 29000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 29001 to 30000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 30001 to 31000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 31001 to 32000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 32001 to 33000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 33001 to 34000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 34001 to 35000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 35001 to 36000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 36001 to 37000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 37001 to 38000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 38001 to 39000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 39001 to 40000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 40001 to 41000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 41001 to 42000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 42001 to 43000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 43001 to 44000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 44001 to 45000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 45001 to 46000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 46001 to 47000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 47001 to 48000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 48001 to 49000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 49001 to 50000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 50001 to 51000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 51001 to 52000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 52001 to 53000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 53001 to 54000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 54001 to 55000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 55001 to 56000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 56001 to 57000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 57001 to 58000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 58001 to 59000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 59001 to 60000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 60001 to 61000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 61001 to 62000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 62001 to 63000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 63001 to 64000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 64001 to 65000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 65001 to 66000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 66001 to 67000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 67001 to 68000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 68001 to 69000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 69001 to 70000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 70001 to 71000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 71001 to 72000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 72001 to 73000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 73001 to 74000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 74001 to 75000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 75001 to 76000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 76001 to 77000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 77001 to 78000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 78001 to 79000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 79001 to 80000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 80001 to 81000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 81001 to 82000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 82001 to 83000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 83001 to 84000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 84001 to 85000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 85001 to 86000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 86001 to 87000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 87001 to 88000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 88001 to 89000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 89001 to 90000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 90001 to 91000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 91001 to 92000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 92001 to 93000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 93001 to 94000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 94001 to 95000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 95001 to 96000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 96001 to 97000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 97001 to 98000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 98001 to 99000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 99001 to 100000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 100001 to 101000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 101001 to 102000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 102001 to 103000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 103001 to 104000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 104001 to 105000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 105001 to 106000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 106001 to 107000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 107001 to 108000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 108001 to 109000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 109001 to 110000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 110001 to 111000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 111001 to 112000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 112001 to 113000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 113001 to 114000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 114001 to 115000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 115001 to 116000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 116001 to 117000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 117001 to 118000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 118001 to 119000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 119001 to 120000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 120001 to 121000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 121001 to 122000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 122001 to 123000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 123001 to 124000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 124001 to 125000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 125001 to 126000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 126001 to 127000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 127001 to 128000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 128001 to 129000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 129001 to 130000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 130001 to 131000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 131001 to 132000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 132001 to 133000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 133001 to 134000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 134001 to 135000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 135001 to 136000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 136001 to 137000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 137001 to 138000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 138001 to 139000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 139001 to 140000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 140001 to 141000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 141001 to 142000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 142001 to 143000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 143001 to 144000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 144001 to 145000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 145001 to 146000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 146001 to 147000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 147001 to 148000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 148001 to 149000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 149001 to 150000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 150001 to 151000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 151001 to 152000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 152001 to 153000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 153001 to 154000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 154001 to 155000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 155001 to 156000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 156001 to 157000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 157001 to 158000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 158001 to 159000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 159001 to 160000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 160001 to 161000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 161001 to 162000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 162001 to 163000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 163001 to 164000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 164001 to 165000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 165001 to 166000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 166001 to 167000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 167001 to 168000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 168001 to 169000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 169001 to 170000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 170001 to 171000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 171001 to 172000...
# Data appended to CSV file: hotelbeds_data.csv
# Fetching hotels from 172001 to 173000...
# Data appended to CSV file: hotelbeds_data.csv
# Data dump process completed.
